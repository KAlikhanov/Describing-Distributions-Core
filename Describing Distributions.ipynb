# %%
# Importing Libraries.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Importing data.
df = pd.read_csv('data(1).csv')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %% [markdown]
# ## Visualizations:

# %%
# VitD_levels
plt.style.use('seaborn')
fig, ax = plt.subplots(figsize=(10,10))
sns.histplot(x=df['VitD_levels'],kde=True,ax=ax)
ax.set_title('Vitamin D Levels Histogram')

mean = np.mean(df['VitD_levels'])
median = np.median(df['VitD_levels'])
std = df['VitD_levels'].std()
plus_one_std = mean + std
minus_one_std = mean - std

ax.axvline(mean, ls='--',lw=3, label=f"Vitamin D Levels (Mean={mean:.2f})",color='Red')
ax.axvline(median, ls='--', lw=3, label=f"Vitamin D Levels (Median={median:.2f})",color = 'Green')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0, alpha = 0.4)

plt.legend()
plt.tight_layout()

# %% [markdown]
#  Vitamin D Levels:
#  - This data is continuous.
#  - This is a normal distribution so no skew.
#  - I believe this is mesokurtic.

# %%
# Doc_visits
fig, ax = plt.subplots(figsize=(10,10))
sns.histplot(x=df['Doc_visits'],kde=True,ax=ax)
ax.set_title('Doctor Visits Histogram')

mean = np.mean(df['Doc_visits'])
median = np.median(df['Doc_visits'])
std = df['Doc_visits'].std()
plus_one_std = mean + std
minus_one_std = mean - std

ax.axvline(mean, ls='--',lw=3, label=f"Doctor Visits (Mean={mean:.2f})",color='Red')
ax.axvline(median, ls='--', lw=3, label=f"Doctor Visits (Median={median:.2f})",color = 'Green')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0, alpha = 0.4)

plt.legend()
plt.tight_layout()

# %% [markdown]
# Doctor Visits:
# - This is discrete data.
# - Looks normal so no skew.
# - I would probably say this  is leptokurtic.

# %%
# TotalCharge
fig, ax = plt.subplots(figsize=(10,10))
sns.histplot(x=df['TotalCharge'],kde=True,ax=ax)
ax.set_title('Total Charges Histogram')

mean = np.mean(df['TotalCharge'])
median = np.median(df['TotalCharge'])
std = df['TotalCharge'].std()
plus_one_std = mean + std
minus_one_std = mean - std

ax.axvline(mean, ls='--',lw=3, label=f"Total Charges (Mean={mean:.2f})",color='Red')
ax.axvline(median, ls='--', lw=3, label=f"Total Charge (Median={median:.2f})",color = 'Green')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0, alpha = 0.4)

plt.legend()
plt.tight_layout()

# %% [markdown]
# Total Charges:
# - This is continuous data.
# - It has a slightly negative skew.
# - This looks mesokurtic.
